# %% [markdown]
# # Test02

# %% [markdown]
# ## 제 1유형
# - 데이터셋 : https://raw.githubusercontent.com/YoungjinBD/dataset/main/HR-Employee-Attrition.csv

# %% [markdown]
# ### 문제1) 데이터에서 'Attrition'은 퇴사여부에 대한 종속변수에 해당한다. 종속변수의 값을 다음과 같은 수치로 변환해 새 컬럼으로 추가하고 각 범주별 레코드 수를 계산하시오. (Yes-1, No-0)

# %%
import pandas as pd 
import numpy as np 

dataset_path = "https://raw.githubusercontent.com/YoungjinBD/dataset/main/HR-Employee-Attrition.csv"
df_HR = pd.read_csv(dataset_path)

df_HR.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
def change_dataset(content):
    if content == "Yes":
        output = 1
    elif content == "No":
        output = 0
    else:
        output = None
    return output

df_HR['New_Attrition'] = df_HR['Attrition'].apply(change_dataset)
df_HR[['Attrition', 'New_Attrition']].head()
# Out:
#   Attrition  New_Attrition
# 0       Yes              1
# 1        No              0
# 2       Yes              1
# 3        No              0
# 4        No              0

# %%
df_HR['New_Attrition'].value_counts()
# Out:
# New_Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64

# %%
# 다른방법) 레이블 인코딩으로 해도 됨
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df_HR['New_Attrition'] = encoder.fit_transform(df_HR['Attrition'])
df_HR['New_Attrition'].value_counts()
# Out:
# New_Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64

# %% [markdown]
# ### 문제2) 데이터셋의 데이터타입별 컬럼 개수를 계산하고, 범주형 변수 중 유일한 값을 1개만 가지고 있는 컬럼(변수)을 찾아내어 그 변수를 데이터에서 제거하시오.

# %%
print(df_HR.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
cat_feat = df_HR.select_dtypes('object', 'category').columns.values
df_cat = df_HR[cat_feat].copy()
df_cat.nunique().sort_values
# Out:
# <bound method Series.sort_values of Attrition         2
# BusinessTravel    3
# Department        3
# EducationField    6
# Gender            2
# JobRole           9
# MaritalStatus     3
# Over18            1
# OverTime          2
# dtype: int64>

# %%
df_cat = df_cat.drop(['Over18'], axis=1)
df_cat
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus OverTime
# ...

# %% [markdown]
# ### 문제3) 원래 데이터에서 숫자형인 컬럼(변수)만 추출하여 새로운 데이터프레임을 생성하고, 각 변수간의 상관계수(피어슨 상관계수)를 구하고 상관계수가 0.9이상인 두 개의 컬럼을 찾아내어 그 변수 중 하나를 제거하시오.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
df_HR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
num_feat = df_HR.select_dtypes('number').columns.values
df_num = df_HR[num_feat].copy()

df_num.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EmployeeCount  EmployeeNumber  \
# 0   41       1102                 1          2              1               1
# 1   49        279                 8          1              1               2
# 2   37       1373                 2          2              1               4
# 3   33       1392                 3          4              1               5
# 4   27        591                 2          1              1               7
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  ...  \
# 0                        2          94               3         2  ...
# 1                        3          61               2         2  ...
# 2                        4          92               2         1  ...
# 3                        4          56               3         1  ...
# 4                        1          40               3         1  ...
#
# ...

# %%
corr = df_num.corr(method="pearson")
corr.shape
# Out:
# (27, 27)

# %%
for i in range(0, 24):
    for j in range(i+1, 25):
        if (corr.iloc[i, j] >= 0.9):
            print(i, j, corr.iloc[i, j])
# Out:
# 9 11 0.9502999134798473

# %%
corr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, Age to New_Attrition
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       25 non-null     float64
#  1   DailyRate                 25 non-null     float64
#  2   DistanceFromHome          25 non-null     float64
#  3   Education                 25 non-null     float64
#  4   EmployeeCount             0 non-null      float64
#  5   EmployeeNumber            25 non-null     float64
#  6   EnvironmentSatisfaction   25 non-null     float64
#  7   HourlyRate                25 non-null     float64
#  8   JobInvolvement            25 non-null     float64
#  9   JobLevel                  25 non-null     float64
#  10  JobSatisfaction           25 non-null     float64
#  11  MonthlyIncome             25 non-null     float64
#  12  MonthlyRate               25 non-null     float64
# ...

# %%
df_num = df_num.drop(["JobLevel"], axis=1, errors='ignore')

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   DailyRate                 1470 non-null   int64
#  2   DistanceFromHome          1470 non-null   int64
#  3   Education                 1470 non-null   int64
#  4   EmployeeCount             1470 non-null   int64
#  5   EmployeeNumber            1470 non-null   int64
#  6   EnvironmentSatisfaction   1470 non-null   int64
#  7   HourlyRate                1470 non-null   int64
#  8   JobInvolvement            1470 non-null   int64
#  9   JobSatisfaction           1470 non-null   int64
#  10  MonthlyIncome             1470 non-null   int64
#  11  MonthlyRate               1470 non-null   int64
#  12  NumCompaniesWorked        1470 non-null   int64
#  13  PercentSalaryHike         1470 non-null   int64
# ...

# %% [markdown]
# ## 제 2유형
# - 데이터셋 : https://raw.githubusercontent.com/YoungjinBD/dataset/main/Parkinsons.csv

# %% [markdown]
# ### 문제
# 데이터셋을 이용하여 파킨슨병을 예측하는 모델을 로지스틱 회귀모형을 적용하여 생성하고, 이때 파키슨병을 예측하는데 영향을 미치는 변수를 중요한 순서대로 3개 선정하시오.
# 이 모델에서 파킨슨병으로 진단하는 기준(threshold, 또는 cutoff)을 0.5로 했을 때와 0.8로 했을 때의 F1-스코어를 비교하고 해석하시오. (단, 다음 조건을 지켜서 물음에 답하시오.)
#
# ```
# 분석 조건
# - 필요 없는 컬럼인 'name'제거
# - 로지스틱 회귀를 위해 상수항 추가
# - 트레이닝셋과 테스트셋의 비율은 9:1
# - 모델의 최적화 방법론으로 "bfgs" 사용
# - 데이터 정규화는 min-max 스케일러 사용
# - status는 카테고리 타입으로 변환
# - 모델은 로지스틱 회귀분석 사용
# ```

# %%
import pandas as pd
import numpy as np
import sklearn as sk

dataset_path = "https://raw.githubusercontent.com/YoungjinBD/dataset/main/Parkinsons.csv"
df_parkinson = pd.read_csv(dataset_path)

df_parkinson.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df_parkinson_drop = df_parkinson.drop(['name'], axis=1, inplace=False)
df_parkinson_drop
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
df_parkinson_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MDVP:Fo(Hz)       195 non-null    float64
#  1   MDVP:Fhi(Hz)      195 non-null    float64
#  2   MDVP:Flo(Hz)      195 non-null    float64
#  3   MDVP:Jitter(%)    195 non-null    float64
#  4   MDVP:Jitter(Abs)  195 non-null    float64
#  5   MDVP:RAP          195 non-null    float64
#  6   MDVP:PPQ          195 non-null    float64
#  7   Jitter:DDP        195 non-null    float64
#  8   MDVP:Shimmer      195 non-null    float64
#  9   MDVP:Shimmer(dB)  195 non-null    float64
#  10  Shimmer:APQ3      195 non-null    float64
#  11  Shimmer:APQ5      195 non-null    float64
#  12  MDVP:APQ          195 non-null    float64
#  13  Shimmer:DDA       195 non-null    float64
#  14  NHR               195 non-null    float64
#  15  HNR               195 non-null    float64
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

MMscaler = MinMaxScaler()

df_parkinson_preprocessing = MMscaler.fit_transform(df_parkinson_drop)
df_parkinson_preprocessed = pd.DataFrame(df_parkinson_preprocessing)
df_parkinson_preprocessed.columns = df_parkinson_drop.columns

df_parkinson_preprocessed.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0     0.184308      0.112592      0.054815        0.195680          0.249012
# 1     0.198327      0.094930      0.278323        0.254130          0.288538
# 2     0.165039      0.059128      0.265288        0.280178          0.328063
# 3     0.165004      0.072927      0.264200        0.263342          0.328063
# 4     0.161150      0.080909      0.260107        0.354511          0.407115
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0  0.145472  0.247588    0.145288      0.312215          0.280197  ...
# 1  0.191233  0.323687    0.191042      0.472887          0.444536  ...
# 2  0.229287  0.369239    0.229411      0.390634          0.326212  ...
# 3  0.209056  0.324759    0.208862      0.414278          0.354971  ...
# 4  0.282755  0.437299    0.282870      0.499452          0.410025  ...
#
#    Shimmer:DDA       NHR       HNR  status      RPDE       DFA   spread1  \
# ...
